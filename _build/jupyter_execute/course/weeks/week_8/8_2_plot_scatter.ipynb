# %% [markdown]
# ## plot ו-scatter: קווים, נקודות וסגנון
#
# ב-Matplotlib יש שתי פונקציות ציור עיקריות שרלוונטיות כמעט לכל דוח מעבדה:
#
# - **`ax.plot(x, y)`** — מתאימה ל**עקומה רציפה**: מודל תיאורטי, פונקציה מחושבת על רשת צפופה של נקודות.
# - **`ax.scatter(x, y)`** — מתאימה ל**נקודות בדידות**: מדידות בפועל, שאין ביניהן קשר רציף מובנה.
#
# ההבחנה הזו אינה טכנית בלבד — היא משקפת הבדל פיזיקלי: בדוח מעבדה מקובל לצייר את המודל התיאורטי כקו רציף, ואת המדידות כנקודות נפרדות עליו.

# %% [markdown]
# ### דוגמה: מודל תיאורטי מול "מדידות" עם רעש
#
# ניצור את מסלול הזריקה $y(x)$ (גובה כתלות במרחק אופקי) עבור $\theta=45^\circ$ כעקומה רציפה, ולצידה כמה נקודות "מדידה" על אותו מסלול, עם רעש אקראי קטן שמדמה אי-דיוק של מכשיר מדידה.

# %%
import numpy as np
import matplotlib.pyplot as plt

g, v0 = 9.8, 20.0          # m/s^2, m/s
rng = np.random.default_rng(0)
theta = np.radians(45)
t_flight = 2 * v0 * np.sin(theta) / g

t_full = np.linspace(0, t_flight, 200)
x_full = v0 * np.cos(theta) * t_full
y_full = v0 * np.sin(theta) * t_full - 0.5 * g * t_full**2

t_meas = np.linspace(0, t_flight, 8)
x_meas = v0 * np.cos(theta) * t_meas
y_meas = v0 * np.sin(theta) * t_meas - 0.5 * g * t_meas**2 + rng.normal(0, 0.3, size=t_meas.size)

fig, ax = plt.subplots()
ax.plot(x_full, y_full, color="tab:blue", label="מודל תיאורטי")
ax.scatter(x_meas, y_meas, color="tab:red", marker="o", label='"מדידות" (עם רעש)')
ax.set_xlabel("x (m)")
ax.set_ylabel("y (m)")
ax.legend()
plt.show()

# %% [markdown]
# פרמטרי הסגנון הנפוצים: ב-`plot` — `color`, `linestyle` (`"-"`, `"--"`, `":"`), `linewidth`; ב-`scatter` — `color`, `marker` (`"o"`, `"^"`, `"s"`...), `s` (גודל הנקודה).

# %% [markdown]
# ### נסו בעצמכם
#
# שנו את עקומת המודל לקו מקווקו (`linestyle="--"`) ואת סימוני המדידה למשולשים (`marker="^"`) בגודל `s=60`.

# %%
# fig, ax = plt.subplots()
# ax.plot(x_full, y_full, linestyle=..., ...)
# ax.scatter(x_meas, y_meas, marker=..., s=..., ...)
# ...

# %% [markdown]
# `````{admonition} פתרון
# :class: dropdown, tip
# ```python
# fig, ax = plt.subplots()
# ax.plot(x_full, y_full, color="tab:blue", linestyle="--", label="מודל תיאורטי")
# ax.scatter(x_meas, y_meas, color="tab:red", marker="^", s=60, label='"מדידות" (עם רעש)')
# ax.set_xlabel("x (m)")
# ax.set_ylabel("y (m)")
# ax.legend()
# plt.show()
# ```
# `````

# %% [markdown]
# ### בדקו את עצמכם

# %%
from jupyterquiz import display_quiz

questions = [
    {
        "question": "איזו פונקציה מתאימה יותר לצייר עקומת מודל תיאורטי רציפה?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "ax.scatter", "correct": False, "feedback": "לא — scatter מתאים יותר לנקודות בדידות."},
            {"answer": "ax.bar", "correct": False, "feedback": "לא — bar מיועד לעמודות, לא לעקומה רציפה."},
            {"answer": "ax.hist", "correct": False, "feedback": "לא — hist מיועד להיסטוגרמות של התפלגות נתונים, לא לעקומת מודל."},
            {"answer": "ax.plot", "correct": True, "feedback": "נכון — עקומה רציפה על רשת צפופה של נקודות."}
        ]
    },
    {
        "question": "מה עושה <code>marker=\"^\"</code> בקריאה ל-<code>ax.scatter</code>?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "קובע את צורת סמל הנקודה למשולש", "correct": True, "feedback": "נכון."},
            {"answer": "קובע את צבע הנקודות", "correct": False, "feedback": "לא — הצבע נקבע ב-color."},
            {"answer": "מוסיף קו המחבר בין הנקודות", "correct": False, "feedback": "לא — scatter לא מצייר קו מחבר."},
            {"answer": "קובע את גודל הנקודה", "correct": False, "feedback": "לא — לגודל הנקודה יש פרמטר נפרד, s."}
        ]
    }
]

display_quiz(questions)
# Out:
# <div id="LzMgTeSTUHqf" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #LzMgTeSTUHqf {
#    --jq-multiple-choice-bg: #392061;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
# ...

# %% [markdown]
# ### תרגול עצמי
#
# עבור $\theta=30^\circ$: ציירו את עקומת המודל התיאורטי (`plot`), ופזרו עליה 6 נקודות "מדידה" עם רעש בגודל $\sigma=0.3$ (`scatter`), עם מקרא וכותרת.

# %%
# theta = np.radians(30)
# ...

# %% [markdown]
# `````{admonition} פתרון
# :class: dropdown, tip
# ```python
# theta = np.radians(30)
# t_flight = 2 * v0 * np.sin(theta) / g
#
# t_full = np.linspace(0, t_flight, 200)
# x_full = v0 * np.cos(theta) * t_full
# y_full = v0 * np.sin(theta) * t_full - 0.5 * g * t_full**2
#
# t_meas = np.linspace(0, t_flight, 6)
# x_meas = v0 * np.cos(theta) * t_meas
# y_meas = v0 * np.sin(theta) * t_meas - 0.5 * g * t_meas**2 + rng.normal(0, 0.3, size=t_meas.size)
#
# fig, ax = plt.subplots()
# ax.plot(x_full, y_full, color="tab:blue", label="מודל תיאורטי")
# ax.scatter(x_meas, y_meas, color="tab:red", label='"מדידות"')
# ax.set_xlabel("x (m)")
# ax.set_ylabel("y (m)")
# ax.set_title(r"מסלול הזריקה ($\theta=30^\circ$)")
# ax.legend()
# plt.show()
# ```
# `````
