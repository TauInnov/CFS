# %% [markdown]
# ## כמה עקומות באותו גרף
#
# השוואה בין כמה תרחישים פיזיקליים נעשית בדרך כלל על אותו גרף, לא בגרפים נפרדים. הדפוס הנפוץ: לולאה שבכל איטרציה מוסיפה עקומה נוספת לאותו `ax`, כשלכל עקומה `label` משלה — כדי שהמקרא יבדיל ביניהן.

# %% [markdown]
# ### דוגמה מובילה: מסלול הזריקה עבור שלוש זוויות שיגור
#
# זו הדוגמה שתלווה את שאר השבוע: אותה מהירות התחלתית $v_0$, שלוש זוויות שיגור שונות — כולן על אותו גרף.

# %%
import numpy as np
import matplotlib.pyplot as plt

g, v0 = 9.8, 20.0          # m/s^2, m/s
angles_deg = [30, 45, 60]

fig, ax = plt.subplots()
for angle in angles_deg:
    theta = np.radians(angle)
    t_flight = 2 * v0 * np.sin(theta) / g
    t = np.linspace(0, t_flight, 200)
    x = v0 * np.cos(theta) * t
    y = v0 * np.sin(theta) * t - 0.5 * g * t**2
    ax.plot(x, y, label=fr"$\theta={angle}^\circ$")

ax.set_xlabel("x (m)")
ax.set_ylabel("y (m)")
ax.set_title("מסלול הזריקה עבור שלוש זוויות שיגור")
ax.legend()
plt.show()

# %% [markdown]
# ### באג נפוץ: label קבוע בתוך לולאה
#
# אם כותבים `ax.plot(x, y, label="זריקה")` בתוך הלולאה — כלומר אותו `label` בכל איטרציה — המקרא יציג את אותה תווית שלוש פעמים, במקום להבדיל בין הזוויות. הפתרון: לבנות את המחרוזת דינמית מתוך משתנה הלולאה, כמו ב-`f"..." / fr"..."` שלמעלה.

# %% [markdown]
# ### נסו בעצמכם
#
# הוסיפו לגרף עקומה רביעית עבור $\theta=75^\circ$.

# %%
# fig, ax = plt.subplots()
# for angle in [30, 45, 60, 75]:
#     ...

# %% [markdown]
# `````{admonition} פתרון
# :class: dropdown, tip
# ```python
# fig, ax = plt.subplots()
# for angle in [30, 45, 60, 75]:
#     theta = np.radians(angle)
#     t_flight = 2 * v0 * np.sin(theta) / g
#     t = np.linspace(0, t_flight, 200)
#     x = v0 * np.cos(theta) * t
#     y = v0 * np.sin(theta) * t - 0.5 * g * t**2
#     ax.plot(x, y, label=fr"$\theta={angle}^\circ$")
#
# ax.set_xlabel("x (m)")
# ax.set_ylabel("y (m)")
# ax.legend()
# plt.show()
# ```
# `````

# %% [markdown]
# ### בדקו את עצמכם

# %%
from jupyterquiz import display_quiz

questions = [
    {
        "question": "מה יקרה אם בתוך לולאת ציור נכתוב <code>ax.plot(x, y, label=\"זריקה\")</code> עבור כל זווית?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "המקרא יבדיל אוטומטית בין הזוויות לפי הצבע", "correct": False, "feedback": "הצבע אכן שונה, אבל השאלה היא על תוכן המקרא עצמו."},
            {"answer": "Matplotlib יזרוק שגיאה", "correct": False, "feedback": "לא — זה קוד תקין, רק לא שימושי."},
            {"answer": "רק העקומה האחרונה תופיע בגרף, השאר יימחקו", "correct": False, "feedback": "לא — כל העקומות ייצוירו; הבעיה היא רק בתוכן המקרא, לא בציור עצמו."},
            {"answer": "כל העקומות יופיעו במקרא עם אותה תווית \"זריקה\"", "correct": True, "feedback": "נכון — צריך תווית דינמית התלויה בזווית."}
        ]
    }
]
display_quiz(questions)
# Out:
# <div id="PeuGXjgAysmS" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #PeuGXjgAysmS {
#    --jq-multiple-choice-bg: #392061;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
# ...

# %% [markdown]
# ### תרגול עצמי
#
# ציירו את שלוש הזוויות (30°, 45°, 60°) על אותו גרף, והוסיפו קו אופקי ב-$y=0$ (`ax.axhline(0, color="gray", linewidth=0.8)`) שמייצג את הקרקע.

# %%
# ...

# %% [markdown]
# `````{admonition} פתרון
# :class: dropdown, tip
# ```python
# fig, ax = plt.subplots()
# for angle in [30, 45, 60]:
#     theta = np.radians(angle)
#     t_flight = 2 * v0 * np.sin(theta) / g
#     t = np.linspace(0, t_flight, 200)
#     x = v0 * np.cos(theta) * t
#     y = v0 * np.sin(theta) * t - 0.5 * g * t**2
#     ax.plot(x, y, label=fr"$\theta={angle}^\circ$")
#
# ax.axhline(0, color="gray", linewidth=0.8)
# ax.set_xlabel("x (m)")
# ax.set_ylabel("y (m)")
# ax.legend()
# plt.show()
# ```
# `````
