# %% [markdown]
# ## שמירה לדוח: savefig, dpi, פורמט
#
# צילום מסך של הגרף מהמחברת **אינו** דרך מקובלת לצרף גרף לדוח מעבדה — הרזולוציה נמוכה, ולרוב נחתכות תוויות. הדרך הנכונה: `fig.savefig(...)`.
#
# ```python
# fig.savefig("range_vs_angle.png", dpi=300, bbox_inches="tight")
# ```
#
# - **`dpi`** — רזולוציית השמירה (נקודות לאינץ'); 300 היא רזולוציית הדפסה סבירה, לעומת ברירת המחדל הנמוכה יותר להצגה על מסך.
# - **`bbox_inches="tight"`** — חותך שוליים מיותרים ומוודא שתוויות שלמות (לא נחתכות בקצה).
# - **פורמט הקובץ** נקבע לפי הסיומת: `.png` (רסטר, טוב לתצוגה), `.pdf` או `.svg` (וקטורי — חד גם בהגדלה, מועדף למסמכי LaTeX/Word).

# %% [markdown]
# ### דוגמה: שמירת גרף ההשוואה כקובץ לדוח
#
# נבנה מחדש את גרף הטווח-מול-זווית עם קווי השגיאה (כמו בסעיף 8.9), והפעם נשמור אותו לקובץ.

# %%
import numpy as np
import matplotlib.pyplot as plt

g, v0 = 9.8, 20.0          # m/s^2, m/s
rng = np.random.default_rng(2)
angles_deg = np.array([15, 30, 45, 60, 75])

means, stds = [], []
for angle in angles_deg:
    theta_i = np.radians(angle)
    v0_trials = rng.normal(20.0, 1.0, size=300)
    R_trials = v0_trials**2 * np.sin(2 * theta_i) / g
    means.append(R_trials.mean())
    stds.append(R_trials.std())
means, stds = np.array(means), np.array(stds)

theta_theory = np.radians(np.linspace(0, 90, 200))
R_theory = v0**2 * np.sin(2 * theta_theory) / g

fig, ax = plt.subplots()
ax.plot(np.degrees(theta_theory), R_theory, color="gray", label="תיאוריה")
ax.errorbar(angles_deg, means, yerr=stds, fmt="o", color="tab:red", capsize=4, label='"מדידה" ± שגיאה')
ax.set_xlabel("Launch angle (degrees)")
ax.set_ylabel("Range R (m)")
ax.legend()

fig.savefig("range_vs_angle.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### נסו בעצמכם
#
# שמרו את אותו גרף גם כקובץ `.pdf` (וקטורי) בשם `range_vs_angle.pdf`.

# %%
# fig.savefig("range_vs_angle.pdf", ...)

# %% [markdown]
# `````{admonition} פתרון
# :class: dropdown, tip
# ```python
# fig.savefig("range_vs_angle.pdf", bbox_inches="tight")
# ```
# לקבצים וקטוריים (`.pdf`, `.svg`) `dpi` לא רלוונטי באותו אופן — הם נשארים חדים בכל הגדלה, לא רק ברזולוציה קבועה.
# `````

# %% [markdown]
# ### באג נפוץ: שמירה **אחרי** `()plt.show`
#
# קריאה ל-`()plt.show` יכולה, בסביבות מסוימות, "לנקות" את ה-figure מהזיכרון. הרגל בטוח: לקרוא ל-`fig.savefig(...)` **לפני** `()plt.show`, כמו בדוגמה למעלה — כך שאין תלות בסדר.

# %% [markdown]
# ### בדקו את עצמכם

# %%
from jupyterquiz import display_quiz

questions = [
    {
        "question": "למה עדיף fig.savefig() על פני צילום מסך של הגרף מהמחברת?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "אין שום הבדל מעשי", "correct": False, "feedback": "לא נכון — יש הבדל משמעותי ברזולוציה ובשלמות התוויות."},
            {"answer": "צילום מסך לא נתמך בג'ופיטר בכלל", "correct": False, "feedback": "לא זו הסיבה — טכנית אפשר לצלם מסך, זו פשוט לא הדרך הנכונה."},
            {"answer": "savefig שומר ברזולוציה נשלטת (dpi) ובלי חיתוך תוויות", "correct": True, "feedback": "נכון."},
            {"answer": "כי צילום מסך שומר רק בשחור-לבן", "correct": False, "feedback": "לא נכון — צילום מסך שומר צבע כרגיל; הבעיה היא ברזולוציה ובחיתוך התוויות, לא בצבע."}
        ]
    }
]
display_quiz(questions)
# Out:
# <div id="wvTEnXefDKEp" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #wvTEnXefDKEp {
#    --jq-multiple-choice-bg: #392061;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
# ...

# %% [markdown]
# ### תרגול עצמי
#
# שמרו את גרף שלוש הזוויות מסעיף 8.5 כקובץ `trajectories.png` ב-`dpi=200`, עם `bbox_inches="tight"`.

# %%
# fig, ax = plt.subplots()
# for angle in [30, 45, 60]:
#     ...
# fig.savefig(...)

# %% [markdown]
# `````{admonition} פתרון
# :class: dropdown, tip
# ```python
# fig, ax = plt.subplots()
# for angle in [30, 45, 60]:
#     theta_i = np.radians(angle)
#     t_flight = 2 * v0 * np.sin(theta_i) / g
#     t = np.linspace(0, t_flight, 200)
#     x = v0 * np.cos(theta_i) * t
#     y = v0 * np.sin(theta_i) * t - 0.5 * g * t**2
#     ax.plot(x, y, label=fr"$\theta={angle}^\circ$")
#
# ax.set_xlabel("x (m)")
# ax.set_ylabel("y (m)")
# ax.legend()
#
# fig.savefig("trajectories.png", dpi=200, bbox_inches="tight")
# plt.show()
# ```
# `````
