# %% [markdown]
# ## sort ו-argsort
#
# `np.sort(a)` מחזיר עותק ממוין של המערך. לעיתים קרובות יש לנו כמה מערכים "מקבילים" — לכל איבר במערך אחד יש איבר מתאים באחר (למשל: זמן מדידה וטמפרטורה, לפי אותו סדר ניסויים) — ורוצים למיין את כולם לפי אותו סדר. לשם כך משמש `np.argsort(a)`, שמחזיר לא את הערכים הממוינים אלא את **האינדקסים** שיסדרו את המערך.

# %% [markdown]
# ### דוגמה: גבהי קפיצה במספר ניסויים
#
# מדדנו את הגובה המרבי שכדור הגיע אליו בחמישה ניסויי זריקה, וגם רשמנו את חותמת הזמן (בשניות מתחילת היום) שבה כל ניסוי בוצע. רוצים להציג את הניסויים ממוינים לפי גובה — אך לשמור על ההתאמה לחותמות הזמן.

# %%
import numpy as np
import matplotlib.pyplot as plt

heights = np.array([11.2, 8.9, 14.7, 9.8, 12.5])
timestamps = np.array([540, 555, 561, 570, 588])   # דקה מתחילת המדידות

order = np.argsort(heights)
print("סדר האינדקסים לפי גובה עולה:", order)

heights_sorted = heights[order]
timestamps_sorted = timestamps[order]

print("גבהים ממוינים:", heights_sorted)
print("חותמות זמן בהתאמה:", timestamps_sorted)
# Out:
# סדר האינדקסים לפי גובה עולה: [1 3 0 4 2]
# גבהים ממוינים: [ 8.9  9.8 11.2 12.5 14.7]
# חותמות זמן בהתאמה: [555 570 540 588 561]

# %% [markdown]
# שימו לב: `timestamps[order]` ולא `np.sort(timestamps)` — אילו מיינו כל מערך בנפרד היינו מאבדים את ההתאמה בין ניסוי לניסוי. נציג את זה גרפית:

# %%
fig, ax = plt.subplots()
ax.bar(range(len(heights_sorted)), heights_sorted,
       tick_label=[f"t={ts}" for ts in timestamps_sorted])
ax.set_ylabel("Max height (m)")
ax.set_xlabel("Trial (by timestamp)")
ax.set_title("גבהי קפיצה, ממוינים מהנמוך לגבוה")
plt.show()

# %% [markdown]
# ### נסו בעצמכם
#
# השתמשו ב-`argsort` כדי לסדר את `heights` וגם מערך שלישי, `trial_id`, לפי אותו סדר:

# %%
trial_id = np.array([101, 102, 103, 104, 105])
# order2 = ...
# trial_id_sorted = ...
# print(trial_id_sorted)

# %% [markdown]
# `````{admonition} פתרון
# :class: dropdown, tip
# ```python
# order2 = np.argsort(heights)
# trial_id_sorted = trial_id[order2]
# print(trial_id_sorted)
# ```
# `````

# %% [markdown]
# ### בדקו את עצמכם

# %%
from jupyterquiz import display_quiz

questions = [
    {
        "question": "בהינתן <code>a = np.array([30, 10, 20])</code>, מה מחזיר <code>np.argsort(a)</code>?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "[10, 20, 30] — הערכים הממוינים", "correct": False, "feedback": "זו התוצאה של np.sort(a), לא של argsort."},
            {"answer": "[2, 1, 0] — סדר יורד", "correct": False, "feedback": "לא — argsort ברירת מחדל ממיין בסדר עולה."},
            {"answer": "[1, 2, 0] — האינדקסים שיסדרו את a", "correct": True, "feedback": "נכון: a[1]=10 (הכי קטן), a[2]=20, a[0]=30 (הכי גדול)."},
            {"answer": "[0, 1, 2] — אותם אינדקסים בסדר המקורי", "correct": False, "feedback": "לא — argsort לא מחזיר את הסדר המקורי; הוא מחזיר את הסדר שממיין את a."}
        ]
    }
]

display_quiz(questions)
# Out:
# <div id="cdcDZWBZnNHw" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #cdcDZWBZnNHw {
#    --jq-multiple-choice-bg: #392061;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
# ...

# %% [markdown]
# ### תרגול עצמי
#
# נמדדו זמני נפילה רועשים במספר ניסויים, ולצידם טמפרטורת החדר בזמן כל ניסוי. סדרו את שני המערכים לפי זמן הנפילה, מהקצר לארוך:

# %%
fall_times = np.array([2.03, 1.98, 2.15, 1.87, 2.01])
room_temp = np.array([21.5, 22.0, 20.8, 22.3, 21.7])

# order3 = ...
# fall_times_sorted = ...
# room_temp_sorted = ...
# print(fall_times_sorted, room_temp_sorted)

# %% [markdown]
# `````{admonition} פתרון
# :class: dropdown, tip
# ```python
# order3 = np.argsort(fall_times)
# fall_times_sorted = fall_times[order3]
# room_temp_sorted = room_temp[order3]
# print(fall_times_sorted, room_temp_sorted)
# ```
# `````
