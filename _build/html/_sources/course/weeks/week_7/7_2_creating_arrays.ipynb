# %% [markdown]
# ## יצירת מערכים: array, zeros, ones, arange, linspace
#
# מלבד בנייה מתוך רשימה קיימת (`np.array`), ל-NumPy יש כמה פונקציות ליצירת מערכים ישירות:
#
# - `np.zeros(n)` — מערך של n אפסים, שימושי כ"מכל" ריק שממלאים בהמשך.
# - `np.ones(n)` — מערך של n אחדים.
# - `np.arange(start, stop, step)` — כמו `range` בפייתון, אך מחזיר מערך. **הקצה העליון לא נכלל**.
# - `np.linspace(start, stop, num)` — num נקודות במרווחים שווים בין start ל-stop, **כולל שתי הקצוות**.
#
# ההבדל בין `arange` ל-`linspace` הוא מקור נפוץ לטעויות "בגובה אחד" (off-by-one).

# %% [markdown]
# ### דוגמה: וקטור זמן לזריקה
#
# בסעיף הקודם בנינו את וקטור הזמן של הזריקה כרשימה קבועה מראש. הפעם נבנה אותו ישירות עם `linspace`, ונכין גם מערך ריק לאחסון תוצאה שנחשב בהמשך.

# %%
import numpy as np
import matplotlib.pyplot as plt

g = 9.8
y0, v0 = 0.0, 15.0

t_arr = np.linspace(0, 3, 10)   # 10 נקודות בין 0 ל-3, כולל שתי הקצוות
y_arr = np.zeros(t_arr.size)    # מכל ריק לתוצאה

y_arr = y0 + v0 * t_arr - 0.5 * g * t_arr**2
print(t_arr)
print(y_arr)
# Out:
# [0.         0.33333333 0.66666667 1.         1.33333333 1.66666667
#  2.         2.33333333 2.66666667 3.        ]
# [ 0.          4.45555556  7.82222222 10.1        11.28888889 11.38888889
#  10.4         8.32222222  5.15555556  0.9       ]

# %% [markdown]
# ### נסו בעצמכם
#
# בנו מערך של תשע זוויות שיגור אפשריות, במרווחים שווים בין 0 ל-90 מעלות (כולל שתי הקצוות):

# %%
# angles = ...
# print(angles)

# %% [markdown]
# `````{admonition} פתרון
# :class: dropdown, tip
# ```python
# angles = np.linspace(0, 90, 9)
# print(angles)
# ```
# `````

# %% [markdown]
# ### arange מול linspace
#
# נשווה ישירות בין שתי הפונקציות על אותו טווח, כדי לראות את ההבדל בהתנהגות בקצה העליון:

# %%
a = np.arange(0, 10, 2)     # לא כולל 10
b = np.linspace(0, 10, 5)    # כולל 10

fig, ax = plt.subplots(figsize=(6, 1.5))
ax.plot(a, np.zeros_like(a), 'o', label="arange(0,10,2)")
ax.plot(b, np.ones_like(b), 'o', label="linspace(0,10,5)")
ax.set_yticks([0, 1])
ax.set_yticklabels(["arange", "linspace"])
ax.set_xlabel("Value")
ax.legend(loc="upper right", bbox_to_anchor=(1.3, 1))
plt.show()

# %% [markdown]
# ### בדקו את עצמכם

# %%
from jupyterquiz import display_quiz

questions = [
    {
        "question": "מה האורך של המערך שמוחזר על ידי <code>np.arange(0, 10, 2)</code>?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "6", "correct": False, "feedback": "לא — arange אינו כולל את הקצה העליון."},
            {"answer": "5", "correct": True, "feedback": "נכון: 0, 2, 4, 6, 8 — חמישה איברים, 10 אינו נכלל."},
            {"answer": "4", "correct": False, "feedback": "לא — יש 5 איברים: 0, 2, 4, 6, 8."},
            {"answer": "10", "correct": False, "feedback": "לא — step=2 קובע קפיצה בין הערכים, לא מספר איברים."}
        ]
    },
    {
        "question": "מה האורך של המערך שמוחזר על ידי <code>np.linspace(0, 10, 5)</code>?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "4", "correct": False, "feedback": "לא — linspace כולל את שתי הקצוות."},
            {"answer": "50", "correct": False, "feedback": "לא — זהו מספר הנקודות, לא צעד."},
            {"answer": "5", "correct": True, "feedback": "נכון: הפרמטר השלישי ב-linspace הוא מספר הנקודות עצמו, כולל שתי הקצוות."},
            {"answer": "0", "correct": False, "feedback": "לא — linspace עם תחום לא-אפס ו-5 נקודות בהחלט מחזיר איברים."}
        ]
    }
]

display_quiz(questions)

# %% [markdown]
# ### תרגול עצמי
#
# רוצים לבדוק תשעה זמני מדידה בקצב קבוע של 0.25 שניות, החל מ-$t=0$ (ועד תשעה איברים בסך הכול). בנו מערך כזה בעזרת `arange`, ובנפרד — מערך זהה בעזרת `linspace`, ובדקו שהם שווים.

# %%
# t_a = ...   # בעזרת arange
# t_b = ...   # בעזרת linspace
# print(np.allclose(t_a, t_b))

# %% [markdown]
# `````{admonition} פתרון
# :class: dropdown, tip
# ```python
# t_a = np.arange(0, 2.25, 0.25)
# t_b = np.linspace(0, 2, 9)
# print(np.allclose(t_a, t_b))
# ```
# `````
