# %% [markdown]
# # שבוע 12 — בקרת גרסאות עם Git
# בשבוע האחרון של הקורס נלמד כלי שהוא לא עוד ספרייה כמו NumPy או pandas, אלא הרגלת עבודה: **Git**, מערכת בקרת הגרסאות הנפוצה בעולם.
# כל פיזיקאי שעובד עם קוד מכיר את הרגע שבו קובץ בשם `sim_v2_final_REAL.py` מפסיק להיות מצחיק — שינוי "קטן" שמשבש קוד עובד, בלי אפשרות לחזור אחורה, או שני שותפי מעבדה שדורכים על השינויים אחד של השני.
# Git פותר את זה: הוא שומר **היסטוריה** מלאה של הקוד שלכם, תמונת מצב אחרי תמונת מצב, כל אחת מתועדת ובת-שחזור.
# לא נלמד את כל Git — שבוע אחד לא מספיק לזה — אלא בדיוק את מה שמכסה 90% מהשימוש היומיומי של מדען שעובד לבד או בזוג: לשמור היסטוריה, לקרוא אותה, לגבות אותה ל-GitHub, ולשרוד קונפליקט מיזוג אחד בלי בהלה.
# בסוף השבוע תדעו:
# - למה בקרת גרסאות פותרת בעיה שכל אחד מכיר, ולמה Ctrl+Z ותיקיות v1/v2 לא מספיקות
# - ליצור repo ולשמור היסטוריה עם `git init`, `add`, `commit`
# - לקרוא היסטוריה קיימת ולאתר בה באגים עם `git log`, `git diff`, `git status`
# - להחליט מה לא שייך ל-Git עם `.gitignore`
# - לגבות ולשתף קוד עם GitHub — `remote`, `push`, `clone`, `pull`
# - להסתעף עם branch, ולפתור merge conflict אחד בביטחון
# **Materials**
# - {doc}`1 • למה בקרת גרסאות <../../course/weeks/week_12/12_1_why_version_control>`
# - {doc}`2 • snapshot אחד בכל פעם: git init, add, commit <../../course/weeks/week_12/12_2_init_add_commit>`
# - {doc}`3 • לקרוא את ההיסטוריה: git log, diff, status <../../course/weeks/week_12/12_3_log_diff_status>`
# - {doc}`4 • מה לא לשים ב-Git: .gitignore <../../course/weeks/week_12/12_4_gitignore>`
# - {doc}`5 • גיבוי ושיתוף: GitHub — remote, clone, push, pull <../../course/weeks/week_12/12_5_github_remote>`
# - {doc}`6 • בסיס שיתוף פעולה: branch ו-merge conflict <../../course/weeks/week_12/12_6_branch_merge>`
